# %%
import pandas as pd
import random
random.seed(42)

# %% [markdown]
# ## Hoteles obtenidos de datosgob_2024.csv

# %% [markdown]
# ### Carga y filtrado de registros por hoteles

# %%
df = pd.read_csv('./datosgob_2024.csv', encoding='latin-1')

# %%
df_hotels = df[df.Giro.str.contains('hotel', case=False, na=False, regex=True)]
df_hotels
# Out:
#                         Razón Social            Estado            Municipio  \
# 611                      HOTEL COLON            México              Texcoco
# 913             HOTEL DULCE AMANECER            México             Timilpan
# 1014              VILLAS DE SAN JOSE            México        Tianguistenco
# 1138    IMPULSORA PLAZA DE ZACATECAS            México  Tlalnepantla de Baz
# 2007                HOTEL LA MURALLA            México               Toluca
# ...                              ...               ...                  ...
# 147551               PLAZA CAMARONES  Ciudad de México         Azcapotzalco
# 147636                        ESDISA  Ciudad de México         Azcapotzalco
# 147674            HOTELERA CAMARONES  Ciudad de México         Azcapotzalco
# 147779  HOTEL RESTAURANTE LAS GARZAS           Yucatán             Progreso
# 147802          HOTEL PROGRESO BEACH           Yucatán             Progreso
#
#                                                 Domicilio  \
# 611                                 Calle COLON 218 int 0
# 913                    Calle TULIPAN, MANZANA 3 120 int -
# 1014            Carretera LA MARQUESA TENANGO KM 23 int -
# 1138                        Avenida GUSTAVO BAZ 29 int NA
# 2007                    Avenida PASEO TOLLOCAN 1098 int -
# ...                                                   ...
# 147551                  Calle CUITLAHUAC 3369 int NINGUNO
# 147636  Calzada EJE UNO PONIENTE CALZADA VALLEJO 535 i...
# 147674                  Calzada CAMARONES 575 int NINGUNO
# 147779                           Calle 17 742 int NINGUNA
# 147802                               Calle 21 150 int N/A
#
#                                Colonia   C.P.    Teléfono  \
# 611                     Colonia CENTRO  56100  5959546946
# 913        Colonia LOMAS DE SAN MIGUEL  52928  5889966315
# 1014                    Colonia CENTRO  52600  7131330969
# 1138              Colonia XOCOYAHUALCO  54080  5576077000
# 2007    Colonia SANTA ANA TLAPALTITLÁN  50160  7221991051
# ...                                ...    ...         ...
# 147551             Colonia SAN BERNABE   2830  5550605307
# 147636      Colonia INDUSTRIAL VALLEJO   2300  5550605307
# 147674   Colonia SANTA MARIA MANINALCO   2050  5532321808
# 147779                  Colonia CENTRO  97322  9995544222
# 147802         Colonia CENTRO PROGRESO  97320  9699355079
#
#                                    E-mail  \
# 611                 elhuero23@hotmail.com
# 913          reynajimenez.ger@outlook.com
# 1014       hotelvillasdesanjose@gmail.com
# 1138    cebaz.contador@cityexpress.con.mx
# 2007              vermello@prodigy.net.mx
# ...                                   ...
# 147551     permisoslegales.2023@gmail.com
# 147636     permisoslegales.2023@gmail.com
# 147674  JVAZQUEZRO@BURODECONNSULTORIA.COM
# 147779        facturas@hotellasgarzas.com
# 147802       CIELO_MEDINA1453@HOTMAIL.COM
#
#                                           Giro   SCIAN Rango de Empleados  \
# 611                                      HOTEL  721112            11 a 50
# 913                                      HOTEL  721112             0 a 10
# 1014                                     HOTEL  721112             0 a 10
# 1138                                     HOTEL  721111             0 a 10
# 2007    Hoteles con otros servicios integrados  721111             0 a 10
# ...                                        ...     ...                ...
# 147551                                   HOTEL  721111            11 a 50
# 147636    HOTEL CON OTROS SERVICIOS INTEGRADOS  721111             0 a 10
# 147674                                   HOTEL  721111            11 a 50
# 147779                                   HOTEL  721112             0 a 10
# 147802      SERVICIO DE HOTEL Y GUIA TURISTICO  721112            11 a 50
#
#                           Registrado por
# 611              CANACO SERVYTUR TEXCOCO
# 913               CANACO SERVYTUR TOLUCA
# 1014              CANACO SERVYTUR TOLUCA
# 1138        CANACO SERVYTUR TLALNEPANTLA
# 2007              CANACO SERVYTUR TOLUCA
# ...                                  ...
# 147551  CANACO SERVYTUR CIUDAD DE MEXICO
# 147636  CANACO SERVYTUR CIUDAD DE MEXICO
# 147674  CANACO SERVYTUR CIUDAD DE MEXICO
# 147779            CANACO SERVYTUR MERIDA
# 147802            CANACO SERVYTUR MERIDA
#
# [1309 rows x 12 columns]

# %%
df_hotels = df_hotels.drop(columns = ['SCIAN', 'Rango de Empleados', 'Registrado por', 'Giro'])
df_hotels = df_hotels.rename(columns={ 'C.P.': 'CP' })
df_hotels
# Out:
#                         Razón Social            Estado            Municipio  \
# 611                      HOTEL COLON            México              Texcoco
# 913             HOTEL DULCE AMANECER            México             Timilpan
# 1014              VILLAS DE SAN JOSE            México        Tianguistenco
# 1138    IMPULSORA PLAZA DE ZACATECAS            México  Tlalnepantla de Baz
# 2007                HOTEL LA MURALLA            México               Toluca
# ...                              ...               ...                  ...
# 147551               PLAZA CAMARONES  Ciudad de México         Azcapotzalco
# 147636                        ESDISA  Ciudad de México         Azcapotzalco
# 147674            HOTELERA CAMARONES  Ciudad de México         Azcapotzalco
# 147779  HOTEL RESTAURANTE LAS GARZAS           Yucatán             Progreso
# 147802          HOTEL PROGRESO BEACH           Yucatán             Progreso
#
#                                                 Domicilio  \
# 611                                 Calle COLON 218 int 0
# 913                    Calle TULIPAN, MANZANA 3 120 int -
# 1014            Carretera LA MARQUESA TENANGO KM 23 int -
# 1138                        Avenida GUSTAVO BAZ 29 int NA
# 2007                    Avenida PASEO TOLLOCAN 1098 int -
# ...                                                   ...
# 147551                  Calle CUITLAHUAC 3369 int NINGUNO
# 147636  Calzada EJE UNO PONIENTE CALZADA VALLEJO 535 i...
# 147674                  Calzada CAMARONES 575 int NINGUNO
# 147779                           Calle 17 742 int NINGUNA
# 147802                               Calle 21 150 int N/A
#
#                                Colonia     CP    Teléfono  \
# 611                     Colonia CENTRO  56100  5959546946
# 913        Colonia LOMAS DE SAN MIGUEL  52928  5889966315
# 1014                    Colonia CENTRO  52600  7131330969
# 1138              Colonia XOCOYAHUALCO  54080  5576077000
# 2007    Colonia SANTA ANA TLAPALTITLÁN  50160  7221991051
# ...                                ...    ...         ...
# 147551             Colonia SAN BERNABE   2830  5550605307
# 147636      Colonia INDUSTRIAL VALLEJO   2300  5550605307
# 147674   Colonia SANTA MARIA MANINALCO   2050  5532321808
# 147779                  Colonia CENTRO  97322  9995544222
# 147802         Colonia CENTRO PROGRESO  97320  9699355079
#
#                                    E-mail
# 611                 elhuero23@hotmail.com
# 913          reynajimenez.ger@outlook.com
# 1014       hotelvillasdesanjose@gmail.com
# 1138    cebaz.contador@cityexpress.con.mx
# 2007              vermello@prodigy.net.mx
# ...                                   ...
# 147551     permisoslegales.2023@gmail.com
# 147636     permisoslegales.2023@gmail.com
# 147674  JVAZQUEZRO@BURODECONNSULTORIA.COM
# 147779        facturas@hotellasgarzas.com
# 147802       CIELO_MEDINA1453@HOTMAIL.COM
#
# [1309 rows x 8 columns]

# %%
df_hotels['tipo_hospedaje'] = ['Hotel' for _ in range(len(df_hotels))]
df_hotels['id_propietario'] = [x+1 for x in range(len(df_hotels))]
df_hotels
# Out:
#                         Razón Social            Estado            Municipio  \
# 611                      HOTEL COLON            México              Texcoco
# 913             HOTEL DULCE AMANECER            México             Timilpan
# 1014              VILLAS DE SAN JOSE            México        Tianguistenco
# 1138    IMPULSORA PLAZA DE ZACATECAS            México  Tlalnepantla de Baz
# 2007                HOTEL LA MURALLA            México               Toluca
# ...                              ...               ...                  ...
# 147551               PLAZA CAMARONES  Ciudad de México         Azcapotzalco
# 147636                        ESDISA  Ciudad de México         Azcapotzalco
# 147674            HOTELERA CAMARONES  Ciudad de México         Azcapotzalco
# 147779  HOTEL RESTAURANTE LAS GARZAS           Yucatán             Progreso
# 147802          HOTEL PROGRESO BEACH           Yucatán             Progreso
#
#                                                 Domicilio  \
# 611                                 Calle COLON 218 int 0
# 913                    Calle TULIPAN, MANZANA 3 120 int -
# 1014            Carretera LA MARQUESA TENANGO KM 23 int -
# 1138                        Avenida GUSTAVO BAZ 29 int NA
# 2007                    Avenida PASEO TOLLOCAN 1098 int -
# ...                                                   ...
# 147551                  Calle CUITLAHUAC 3369 int NINGUNO
# 147636  Calzada EJE UNO PONIENTE CALZADA VALLEJO 535 i...
# 147674                  Calzada CAMARONES 575 int NINGUNO
# 147779                           Calle 17 742 int NINGUNA
# 147802                               Calle 21 150 int N/A
#
#                                Colonia     CP    Teléfono  \
# 611                     Colonia CENTRO  56100  5959546946
# 913        Colonia LOMAS DE SAN MIGUEL  52928  5889966315
# 1014                    Colonia CENTRO  52600  7131330969
# 1138              Colonia XOCOYAHUALCO  54080  5576077000
# 2007    Colonia SANTA ANA TLAPALTITLÁN  50160  7221991051
# ...                                ...    ...         ...
# 147551             Colonia SAN BERNABE   2830  5550605307
# 147636      Colonia INDUSTRIAL VALLEJO   2300  5550605307
# 147674   Colonia SANTA MARIA MANINALCO   2050  5532321808
# 147779                  Colonia CENTRO  97322  9995544222
# 147802         Colonia CENTRO PROGRESO  97320  9699355079
#
#                                    E-mail tipo_hospedaje  id_propietario
# 611                 elhuero23@hotmail.com          Hotel               1
# 913          reynajimenez.ger@outlook.com          Hotel               2
# 1014       hotelvillasdesanjose@gmail.com          Hotel               3
# 1138    cebaz.contador@cityexpress.con.mx          Hotel               4
# 2007              vermello@prodigy.net.mx          Hotel               5
# ...                                   ...            ...             ...
# 147551     permisoslegales.2023@gmail.com          Hotel            1305
# 147636     permisoslegales.2023@gmail.com          Hotel            1306
# 147674  JVAZQUEZRO@BURODECONNSULTORIA.COM          Hotel            1307
# 147779        facturas@hotellasgarzas.com          Hotel            1308
# 147802       CIELO_MEDINA1453@HOTMAIL.COM          Hotel            1309
#
# [1309 rows x 10 columns]

# %% [markdown]
# ### Generación de Propietarios a partir de los datos de correo y teléfono

# %%
df_propietarios = pd.DataFrame(df_hotels.filter(['Teléfono', 'E-mail']))
df_propietarios.fillna('Desconocido', axis='columns', inplace=True)

def get_name_from_email(row):
    return row['E-mail'].rsplit('@')[0]

df_propietarios['nombre'] = df_propietarios.apply(get_name_from_email, axis='columns')

df_propietarios
# Out:
#           Teléfono                             E-mail                nombre
# 611     5959546946              elhuero23@hotmail.com             elhuero23
# 913     5889966315       reynajimenez.ger@outlook.com      reynajimenez.ger
# 1014    7131330969     hotelvillasdesanjose@gmail.com  hotelvillasdesanjose
# 1138    5576077000  cebaz.contador@cityexpress.con.mx        cebaz.contador
# 2007    7221991051            vermello@prodigy.net.mx              vermello
# ...            ...                                ...                   ...
# 147551  5550605307     permisoslegales.2023@gmail.com  permisoslegales.2023
# 147636  5550605307     permisoslegales.2023@gmail.com  permisoslegales.2023
# 147674  5532321808  JVAZQUEZRO@BURODECONNSULTORIA.COM            JVAZQUEZRO
# 147779  9995544222        facturas@hotellasgarzas.com              facturas
# 147802  9699355079       CIELO_MEDINA1453@HOTMAIL.COM      CIELO_MEDINA1453
#
# [1309 rows x 3 columns]

# %% [markdown]
# ### Direcciones de hoteles

# %%
import re

def limpiar_calle(domicilio):
    # Elimina contenido tipo "int X", "int S/N", "int N/A"
    domicilio = re.sub(r'\bint\b\s*[\w\./-]+', '', domicilio, flags=re.IGNORECASE)

    # Elimina "KM", "KM.", "KILÓMETRO", con número o decimal
    domicilio = re.sub(r'\bK(M|IL[ÓO]METRO)?\.?\s*\d+(\.\d+)?', '', domicilio, flags=re.IGNORECASE)

    # Elimina número exterior si está justo después del nombre de la calle
    domicilio = re.sub(r'\s+\d+\b', '', domicilio)

    # Elimina múltiples espacios
    domicilio = re.sub(r'\s{2,}', ' ', domicilio)

    # Quita espacios iniciales/finales
    return domicilio.strip()

# Remueve información innecesario del domicilio.
def limpiar_calle_v2(domicilio):
    domicilio = domicilio.strip()

    # Caso especial: si es "Calle [número] [otro número]"
    match = re.match(r'^(Calle\s+\d+)\b(.*)', domicilio, re.IGNORECASE)
    if match:
        return match.group(1)

    # Quitar partes de "int X", "int S/N", etc.
    domicilio = re.sub(r'\bint\b\s*[\w\./-]+', '', domicilio, flags=re.IGNORECASE)

    # Quitar "KM", "KM.", "KILÓMETRO" con número o decimal
    domicilio = re.sub(r'\bK(M|IL[ÓO]METRO)?\.?\s*\d+(\.\d+)?', '', domicilio, flags=re.IGNORECASE)

    # Quitar número exterior (ej. "405", "1234") si no es parte del nombre
    domicilio = re.sub(r'\s+\d+\b', '', domicilio)

    # Quitar múltiples espacios
    domicilio = re.sub(r'\s{2,}', ' ', domicilio)

    return domicilio.strip()

# %%
df_hotels['Domicilio'] = df_hotels['Domicilio'].apply(limpiar_calle_v2)
df_hotels['Domicilio']
# Out:
# 611                                    Calle COLON
# 913                         Calle TULIPAN, MANZANA
# 1014                 Carretera LA MARQUESA TENANGO
# 1138                           Avenida GUSTAVO BAZ
# 2007                        Avenida PASEO TOLLOCAN
#                             ...
# 147551                            Calle CUITLAHUAC
# 147636    Calzada EJE UNO PONIENTE CALZADA VALLEJO
# 147674                           Calzada CAMARONES
# 147779                                    Calle 17
# 147802                                    Calle 21
# Name: Domicilio, Length: 1309, dtype: object

# %%
import requests
from faker import Faker
import time

Faker.seed(42)
fake = Faker("es_MX")

def buscar_direccion_nominatim(calle, ciudad, estado, pais="Mexico", espera=1):
    """
    Consulta la API de Nominatim con datos de dirección y devuelve la respuesta JSON.
    
    Parámetros:
        calle (str): Nombre de la calle (sin número interior).
        ciudad (str): Nombre del municipio o ciudad.
        estado (str): Estado de la República.
        pais (str): País (por defecto 'Mexico').
        espera (int): Tiempo de espera entre solicitudes (segundos).
        
    Retorna:
        dict | None: Primer resultado de la búsqueda o None si no hay resultados.
    """
    url = "https://nominatim.openstreetmap.org/search"
    params = {
        "amenity": 'Hotel cerca', # Obtiene hoteles cercanos a la dirección provista.
        "street": calle,
        "city": ciudad,
        "state": estado,
        "country": pais,
        "format": "jsonv2",
        "addressdetails": 1,
        "extratags": 1,
    }

    headers = {
        'User-Agent': 'metabuscador-dtl',  # Si no se pone un user-agent se enoja la API
        'Accept': 'application/json',  # Para aceptar respuesta en JSON
    }

    try:
        response = requests.get(url, params=params, headers=headers)
        response.raise_for_status()
        resultados = response.json()

        if resultados:
            print(resultados)
            return resultados
        else:
            print('Sin resultados')
            return None
    except requests.RequestException as e:
        print(f"Error en la solicitud: {e}")
        return None
    finally:
        time.sleep(espera)  # Para evitar ser bloqueado por exceso de solicitudes

# Agrega columnas de latitud y longitud
def geocodificar_fila(fila):
    resultado = buscar_direccion_nominatim(fila['Domicilio'], fila['Municipio'], fila['Estado'])
    if resultado:
        return pd.Series([resultado.get('lat'), resultado.get('lon')])
    else:
        return pd.Series([None, None])

def generar_hoteles_con_direccion(fila):
    resultados = buscar_direccion_nominatim(fila['Domicilio'], fila['Municipio'], fila['Estado'])
    if resultados is not None:
        for resultado in resultados:
            hotel = dict()
            propietario = dict()
            direccion = dict()

            hotel['nombre'] = 'Hotel ' + fake.company() if resultado.get('name') == '' else re.sub(r"[^\w\s,]", '', resultado.get('name'), flags=re.UNICODE)
            hotel['precio'] = random.randint(1000, 20000)

            propietario['nombre'] = fake.name()
            propietario['telefono'] = fake.phone_number()
            propietario['email'] = fake.email()

            direccion['nombre'] = resultado.get('address').get('road')
            direccion['estado'] = resultado.get('address').get('state')
            direccion['municipio'] = resultado.get('address').get('county')
            direccion['ciudad'] = resultado.get('address').get('city')
            direccion['cp'] = resultado.get('address').get('postcode')
            direccion['lat'] = resultado.get('lat')
            direccion['lon'] = resultado.get('lon')

            hoteles.append(hotel)
            propietarios.append(propietario)
            direcciones.append(direccion)

# %%
comienzo = 0
fin = 5
hoteles = list()
propietarios = list()
direcciones = list()

df_hotels[comienzo:fin].apply(generar_hoteles_con_direccion, axis=1)
# Out:
# [{'place_id': 290332162, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 6645167088, 'lat': '19.5158352', 'lon': '-98.8856516', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.006639294278488353, 'addresstype': 'tourism', 'name': '', 'display_name': 'Calle Cristóbal Colón, Texcoco de Mora, Texcoco, Estado de México, 56100, México', 'address': {'road': 'Calle Cristóbal Colón', 'city': 'Texcoco de Mora', 'county': 'Texcoco', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '56100', 'country': 'México', 'country_code': 'mx'}, 'extratags': None, 'boundingbox': ['19.5157852', '19.5158852', '-98.8857016', '-98.8856016']}, {'place_id': 287590231, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 263448735, 'lat': '19.51388755', 'lon': '-98.88314016597553', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.009748936324034268, 'addresstype': 'tourism', 'name': '"Iberia"', 'display_name': '"Iberia", Ruta Centro Hisotrico, Texcoco de Mora, Texcoco, Estado de México, 56100, México', 'address': {'tourism': '"Iberia"', 'road': 'Ruta Centro Hisotrico', 'city': 'Texcoco de Mora', 'county': 'Texcoco', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '56100', 'country': 'México', 'country_code': 'mx'}, 'extratags': {'level': '2', 'building': 'yes'}, 'boundingbox': ['19.5137958', '19.5140881', '-98.8832218', '-98.8830495']}, {'place_id': 287421258, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 637920079, 'lat': '19.5221924', 'lon': '-98.88068386089915', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.011526309360835879, 'addresstype': 'tourism', 'name': 'Hotel Villa las Palmas', 'display_name': 'Hotel Villa las Palmas, Diego Rivera, Santiaguito, Chiconcuac, Texcoco de Mora, Texcoco, Estado de México, 56100, México', 'address': {'tourism': 'Hotel Villa las Palmas', 'road': 'Diego Rivera', 'neighbourhood': 'Santiaguito', 'borough': 'Chiconcuac', 'city': 'Texcoco de Mora', 'county': 'Texcoco', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '56100', 'country': 'México', 'country_code': 'mx'}, 'extratags': {'building': 'yes'}, 'boundingbox': ['19.5215797', '19.5227783', '-98.8808540', '-98.8805129']}, {'place_id': 287549313, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 375947695, 'lat': '19.5130488', 'lon': '-98.8806613426676', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.012331818915412624, 'addresstype': 'tourism', 'name': 'First Inn Texcoco', 'display_name': 'First Inn Texcoco, 16 de Septiembre, Texcoco de Mora, Texcoco, Estado de México, 56140, México', 'address': {'tourism': 'First Inn Texcoco', 'road': '16 de Septiembre', 'city': 'Texcoco de Mora', 'county': 'Texcoco', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '56140', 'country': 'México', 'country_code': 'mx'}, 'extratags': {'building': 'yes', 'building:levels': '5'}, 'boundingbox': ['19.5129374', '19.5132425', '-98.8808168', '-98.8805007']}, {'place_id': 287356508, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 186397231, 'lat': '19.514511400000004', 'lon': '-98.87999936242079', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.012345575488330363, 'addresstype': 'tourism', 'name': 'Posada Santa Bertha', 'display_name': 'Posada Santa Bertha, Ruta Centro Hisotrico, Texcoco de Mora, Texcoco, Estado de México, 56100, México', 'address': {'tourism': 'Posada Santa Bertha', 'road': 'Ruta Centro Hisotrico', 'city': 'Texcoco de Mora', 'county': 'Texcoco', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '56100', 'country': 'México', 'count ...
# Sin resultados
# [{'place_id': 286917762, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 9693537293, 'lat': '19.1824244', 'lon': '-99.4140628', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.037401702771305605, 'addresstype': 'tourism', 'name': 'Hotel y Albergue El Fresno', 'display_name': 'Hotel y Albergue El Fresno, Callejón De Jiménez, Colonia Escalerillas, San Juan, Xalatlaco, Estado de México, 52680, México', 'address': {'tourism': 'Hotel y Albergue El Fresno', 'road': 'Callejón De Jiménez', 'neighbourhood': 'Colonia Escalerillas', 'village': 'San Juan', 'town': 'Xalatlaco', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '52680', 'country': 'México', 'country_code': 'mx'}, 'extratags': None, 'boundingbox': ['19.1823744', '19.1824744', '-99.4141128', '-99.4140128']}, {'place_id': 288920725, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 9693537311, 'lat': '19.1813274', 'lon': '-99.4225512', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.039343851029598795, 'addresstype': 'tourism', 'name': 'Hotel Integración Gran', 'display_name': 'Hotel Integración Gran, Avenida Constituyentes, San Agustín, Xalatlaco, Estado de México, 52680, México', 'address': {'tourism': 'Hotel Integración Gran', 'road': 'Avenida Constituyentes', 'village': 'San Agustín', 'town': 'Xalatlaco', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '52680', 'country': 'México', 'country_code': 'mx'}, 'extratags': None, 'boundingbox': ['19.1812774', '19.1813774', '-99.4226012', '-99.4225012']}, {'place_id': 287006716, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 9693537301, 'lat': '19.1785477', 'lon': '-99.4151164', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.04128226558117135, 'addresstype': 'tourism', 'name': 'Hotel La Pirámide', 'display_name': 'Hotel La Pirámide, Avenida Independencia Oriente, San Juan, Xalatlaco, Estado de México, 52680, México', 'address': {'tourism': 'Hotel La Pirámide', 'road': 'Avenida Independencia Oriente', 'village': 'San Juan', 'town': 'Xalatlaco', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '52680', 'country': 'México', 'country_code': 'mx'}, 'extratags': None, 'boundingbox': ['19.1784977', '19.1785977', '-99.4151664', '-99.4150664']}, {'place_id': 290109117, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 9694026880, 'lat': '19.1776441', 'lon': '-99.4144639', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.04218019718895179, 'addresstype': 'tourism', 'name': 'Hotel Paraíso', 'display_name': 'Hotel Paraíso, Avenida 16 De Septiembre, Colonia El Cuandre, San Juan, Xalatlaco, Estado de México, 52680, México', 'address': {'tourism': 'Hotel Paraíso', 'road': 'Avenida 16 De Septiembre', 'neighbourhood': 'Colonia El Cuandre', 'village': 'San Juan', 'town': 'Xalatlaco', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '52680', 'country': 'México', 'country_code': 'mx'}, 'extratags': None, 'boundingbox': ['19.1775941', '19.1776941', '-99.4145139', '-99.4144139']}, {'place_id': 288682862, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1148069345, 'lat': '19.177282650000002', 'lon': '-99.42102248829957', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.0430688704592681, 'addresstype': 'tourism', 'name': '', 'display_name': 'Calle Manuel Negrete, Colonia El Cuandre, San Agustín, Xalatlaco, Estado de México, 52680, México', 'address': {'road': 'Calle Manuel Negrete', 'neighbourhood': 'Colonia El Cuandre', 'village': 'San Agustín', 'town': 'Xalatlaco', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', ' ...
# [{'place_id': 288809236, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4098870935, 'lat': '19.5475794', 'lon': '-99.2104714', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.00473853129722519, 'addresstype': 'tourism', 'name': 'NH Valle Dorado', 'display_name': 'NH Valle Dorado, 3130, Boulevard Manuel Ávila Camacho, Colonia Valle Dorado, Tlalnepantla, Tlalnepantla de Baz, Estado de México, 54020, México', 'address': {'tourism': 'NH Valle Dorado', 'house_number': '3130', 'road': 'Boulevard Manuel Ávila Camacho', 'neighbourhood': 'Colonia Valle Dorado', 'city': 'Tlalnepantla', 'county': 'Tlalnepantla de Baz', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '54020', 'country': 'México', 'country_code': 'mx'}, 'extratags': None, 'boundingbox': ['19.5475294', '19.5476294', '-99.2105214', '-99.2104214']}, {'place_id': 287577420, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 364859737, 'lat': '19.5493801', 'lon': '-99.2075302', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.005018134181538569, 'addresstype': 'tourism', 'name': 'Camino Real Arboledas', 'display_name': 'Camino Real Arboledas, Colonia Valle Dorado, Tlalnepantla, Tlalnepantla de Baz, Estado de México, 54020, México', 'address': {'tourism': 'Camino Real Arboledas', 'road': 'Camino Real Arboledas', 'neighbourhood': 'Colonia Valle Dorado', 'city': 'Tlalnepantla', 'county': 'Tlalnepantla de Baz', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '54020', 'country': 'México', 'country_code': 'mx'}, 'extratags': None, 'boundingbox': ['19.5493301', '19.5494301', '-99.2075802', '-99.2074802']}, {'place_id': 286308805, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1165953713, 'lat': '19.5388581', 'lon': '-99.2033050977882', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.00663171810427222, 'addresstype': 'tourism', 'name': 'Hotel Crowne Plaza Tlalnepantla', 'display_name': 'Hotel Crowne Plaza Tlalnepantla, Calle Roberto Fulton, Tlalnepantla, Tlalnepantla de Baz, Estado de México, 54070, México', 'address': {'tourism': 'Hotel Crowne Plaza Tlalnepantla', 'road': 'Calle Roberto Fulton', 'city': 'Tlalnepantla', 'county': 'Tlalnepantla de Baz', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '54070', 'country': 'México', 'country_code': 'mx'}, 'extratags': {'building': 'yes', 'building:levels': '17'}, 'boundingbox': ['19.5386576', '19.5390658', '-99.2035500', '-99.2030623']}, {'place_id': 288065663, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5594982725, 'lat': '19.5368416', 'lon': '-99.2037348', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.008213572958377055, 'addresstype': 'tourism', 'name': 'Hotel villaporticos', 'display_name': 'Hotel villaporticos, Calle Roberto Fulton, Tlalnepantla, Tlalnepantla de Baz, Estado de México, 54070, México', 'address': {'tourism': 'Hotel villaporticos', 'road': 'Calle Roberto Fulton', 'city': 'Tlalnepantla', 'county': 'Tlalnepantla de Baz', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '54070', 'country': 'México', 'country_code': 'mx'}, 'extratags': None, 'boundingbox': ['19.5367916', '19.5368916', '-99.2037848', '-99.2036848']}, {'place_id': 287503268, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1734181681, 'lat': '19.5391879', 'lon': '-99.2000535', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.008651492208915416, 'addresstype': 'tourism', 'name': 'Fiesta Inn', 'display_name': 'Fiesta Inn, Calle Dunant, Tlalnepantla, Tlalnepantla de Baz, Estado de México, 54000, México', 'address': {'tourism ...
# [{'place_id': 288815657, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 6047989885, 'lat': '19.2891459', 'lon': '-99.6620666', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.015532892753882218, 'addresstype': 'tourism', 'name': 'HOTEL CAZADORES', 'display_name': 'HOTEL CAZADORES, Ciclovía Miguel Hidalgo, Toluca, Estado de México, 50000, México', 'address': {'tourism': 'HOTEL CAZADORES', 'road': 'Ciclovía Miguel Hidalgo', 'city': 'Toluca', 'county': 'Toluca', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '50000', 'country': 'México', 'country_code': 'mx'}, 'extratags': None, 'boundingbox': ['19.2890959', '19.2891959', '-99.6621166', '-99.6620166']}, {'place_id': 288961698, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4724382256, 'lat': '19.2911414', 'lon': '-99.6621367', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.017351955624657345, 'addresstype': 'tourism', 'name': 'Hotel Alameda', 'display_name': 'Hotel Alameda, 104, Calle Ezequiel Ordóñez, Toluca, Estado de México, 50080, México', 'address': {'tourism': 'Hotel Alameda', 'house_number': '104', 'road': 'Calle Ezequiel Ordóñez', 'city': 'Toluca', 'county': 'Toluca', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '50080', 'country': 'México', 'country_code': 'mx'}, 'extratags': {'phone': '01 722 214 3377', 'stars': '2.5', 'internet_access': 'wlan'}, 'boundingbox': ['19.2910914', '19.2911914', '-99.6621867', '-99.6620867']}, {'place_id': 288817195, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 10595233305, 'lat': '19.2901544', 'lon': '-99.6592329', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.017734968905776145, 'addresstype': 'tourism', 'name': 'Hotel Maya', 'display_name': 'Hotel Maya, 413, Avenida Miguel Hidalgo y Costilla, Toluca, Estado de México, 50000, México', 'address': {'tourism': 'Hotel Maya', 'house_number': '413', 'road': 'Avenida Miguel Hidalgo y Costilla', 'city': 'Toluca', 'county': 'Toluca', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '50000', 'country': 'México', 'country_code': 'mx'}, 'extratags': {'phone': '+527222144800'}, 'boundingbox': ['19.2901044', '19.2902044', '-99.6592829', '-99.6591829']}, {'place_id': 286228552, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4726859414, 'lat': '19.2910732', 'lon': '-99.660346', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.018008474790264933, 'addresstype': 'tourism', 'name': 'Hernandez Juarez, Marcelino', 'display_name': 'Hernandez Juarez, Marcelino, 306, Calle Nigromante, Toluca, Estado de México, 50000, México', 'address': {'tourism': 'Hernandez Juarez, Marcelino', 'house_number': '306', 'road': 'Calle Nigromante', 'city': 'Toluca', 'county': 'Toluca', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', 'postcode': '50000', 'country': 'México', 'country_code': 'mx'}, 'extratags': {'phone': '01 722 213 6302'}, 'boundingbox': ['19.2910232', '19.2911232', '-99.6603960', '-99.6602960']}, {'place_id': 288719108, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4724579370, 'lat': '19.2903158', 'lon': '-99.658878', 'category': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': -0.018057058905801084, 'addresstype': 'tourism', 'name': 'Hotel La Casa del Abuelo', 'display_name': 'Hotel La Casa del Abuelo, 404, Avenida Miguel Hidalgo y Costilla, Toluca, Estado de México, 50000, México', 'address': {'tourism': 'Hotel La Casa del Abuelo', 'house_number': '404', 'road': 'Avenida Miguel Hidalgo y Costilla', 'city': 'Toluca', 'county': 'Toluca', 'state': 'Estado de México', 'ISO3166-2-lvl4': 'MX-MEX', ...
# 611     None
# 913     None
# 1014    None
# 1138    None
# 2007    None
# dtype: object

# %%
df_hoteles = pd.DataFrame(hoteles)
df_direcciones = pd.DataFrame(direcciones)
df_propietarios = pd.DataFrame(propietarios)
# Out:
#                                    nombre            estado  \
# 0                   Calle Cristóbal Colón  Estado de México
# 1                   Ruta Centro Hisotrico  Estado de México
# 2                            Diego Rivera  Estado de México
# 3                        16 de Septiembre  Estado de México
# 4                   Ruta Centro Hisotrico  Estado de México
# 5              Boulevard Xochimilco Norte  Estado de México
# 6                      Prolongacion Palma  Estado de México
# 7                           Calle Morelos  Estado de México
# 8                  Cerrada De Los Fresnos  Estado de México
# 9            Carretera a Molino de Flores  Estado de México
# 10                    Callejón De Jiménez  Estado de México
# 11                 Avenida Constituyentes  Estado de México
# 12          Avenida Independencia Oriente  Estado de México
# 13               Avenida 16 De Septiembre  Estado de México
# 14                   Calle Manuel Negrete  Estado de México
# 15                   Calle Manuel Negrete  Estado de México
# 16  Mexicaltzingo-Tianguistengo-Xalatlaco  Estado de México
# 17  Mexicaltzingo-Tianguistengo-Xalatlaco  Estado de México
# 18                    Calle de los Prados  Estado de México
# 19                    Calle de los Prados  Estado de México
# 20         Boulevard Manuel Ávila Camacho  Estado de México
# 21                  Camino Real Arboledas  Estado de México
# 22                   Calle Roberto Fulton  Estado de México
# 23                   Calle Roberto Fulton  Estado de México
# 24                           Calle Dunant  Estado de México
# 25                Avenida de los Maestros  Estado de México
# 26                Avenida de los Maestros  Estado de México
# 27                 Calle Ignacio Zaragoza  Estado de México
# 28               Calle Felipe Berriozábal  Estado de México
# 29                       Calle Cuauhtémoc  Estado de México
# 30                Ciclovía Miguel Hidalgo  Estado de México
# 31                 Calle Ezequiel Ordóñez  Estado de México
# 32      Avenida Miguel Hidalgo y Costilla  Estado de México
# 33                       Calle Nigromante  Estado de México
# 34      Avenida Miguel Hidalgo y Costilla  Estado de México
# 35                    Calle Nicolás Bravo  Estado de México
# 36                       Calle Nigromante  Estado de México
# 37                         Pedro Ascencio  Estado de México
# 38                   Calle Aquiles Serdán  Estado de México
# 39                Ciclovía Miguel Hidalgo  Estado de México
#
#               municipio           ciudad     cp                 lat  \
# 0               Texcoco  Texcoco de Mora  56100          19.5158352
# 1               Texcoco  Texcoco de Mora  56100         19.51388755
# 2               Texcoco  Texcoco de Mora  56100          19.5221924
# 3               Texcoco  Texcoco de Mora  56140          19.5130488
# 4               Texcoco  Texcoco de Mora  56100  19.514511400000004
# 5                  None             None  56280          19.5510646
# 6                  None             None  56280  19.551985799999997
# 7                  None             None  52270          19.5575521
# 8                Atenco             None  56300          19.5524153
# 9               Texcoco  Texcoco de Mora  56130          19.5163239
# 10                 None             None  52680          19.1824244
# 11                 None             None  52680          19.1813274
# 12                 None             None  52680          19.1785477
# 13                 None             None  52680          19.1776441
# 14                 None             None  52680  19.177282650000002
# 15                 None             None  52680          19.1772513
# 16                 None             None  52683          19.1787583
# 17                 None             None  52683          19.1787003
# 18                 None             None  52683          19.1787825
# 19                 None             None  52683          19.1788932
# 20  Tlalnepantla de Baz     Tlalnepantla  54020          19.5475794
# 21  Tlalnepantla de Baz     Tlalnepantla  54020          19.5493801
# 22  Tlalnepantla de Baz     Tlalnepantla  54070          19.5388581
# 23  Tlalnepantla de Baz     Tlalnepantla  54070          19.5368416
# 24  Tlalnepantla de Baz     Tlalnepantla  54000          19.5391879
# 25  Tlalnepantla de Baz     Tlalnepantla  54040          19.5397825
# 26  Tlalnepantla de Baz     Tlalnepantla  54040          19.5407448
# 27  Tlalnepantla de Baz     Tlalnepantla  54000          19.5398875
# 28  Tlalnepantla de Baz     Tlalnepantla  54000          19.5379987
# 29  Tlalnepantla de Baz     Tlalnepantla  54055          19.5235703
# 30               Toluca           Toluca  50000          19.2891459
# 31               Toluca           Toluca  50080          19.2911414
# 32               Toluca           Toluca  50000          19.2901544
# 33               Toluca           Toluca  50000          19.2910732
# 34               Toluca           Toluca  50000          19.2903158
# 35               Toluca           Toluca  50000           19.289652
# 36               Toluca           Toluca  50000         19.29117745
# 37               Toluca           Toluca  50000          19.2911557
# 38               Toluca           Toluca  50000          19.2916404
# 39               Toluca           Toluca  50000          19.2903546
#
#                    lon
# 0          -98.8856516
# 1   -98.88314016597553
# 2   -98.88068386089915
# 3    -98.8806613426676
# 4   -98.87999936242079
# 5   -98.89915188069295
# 6   -98.89499665222533
# 7          -98.8951539
# 8   -98.91334824817596
# 9   -98.84962591624532
# 10         -99.4140628
# 11         -99.4225512
# 12         -99.4151164
# 13         -99.4144639
# 14  -99.42102248829957
# 15         -99.4209979
# 16         -99.4322562
# 17  -99.43222305015932
# 18  -99.43679201924189
# 19         -99.4369317
# 20         -99.2104714
# 21         -99.2075302
# 22   -99.2033050977882
# 23         -99.2037348
# 24         -99.2000535
# 25         -99.2155272
# 26         -99.2178326
# 27         -99.1949928
# 28         -99.1935017
# 29         -99.2277246
# 30         -99.6620666
# 31         -99.6621367
# 32         -99.6592329
# 33          -99.660346
# 34          -99.658878
# 35         -99.6576102
# 36  -99.66018344288335
# 37         -99.6596808
# 38         -99.6596507
# 39         -99.6566372

# %% [markdown]
# ### Incorporación aleatoria de destinos a hoteles

# %%
df_destinos = pd.read_csv('../destinos/destinos.csv')
df_destinos
# Out:
#                 nombre categoria            tipo             ciudad  \
# 0       Cabo San Lucas     place            city     Cabo San Lucas
# 1               Cancún  boundary  administrative             Cancún
# 2               Loreto     place            town            unkwown
# 3    San José del Cabo     place            city  San José del Cabo
# 4               Ixtapa  boundary  administrative            unkwown
# ..                 ...       ...             ...                ...
# 108         Tecozautla  boundary  administrative            unkwown
# 109           Zempoala  boundary  administrative            unkwown
# 110           Coatepec  boundary  administrative            unkwown
# 111            Orizaba     place            city            Orizaba
# 112    Chiapa de Corzo  boundary  administrative            unkwown
#
#            municipio               estado codigopostal        lat         lon  \
# 0          Los Cabos  Baja California Sur        23470  22.893888 -109.920060
# 1      Benito Juárez         Quintana Roo      unkwown  21.152747  -86.842576
# 2             Loreto  Baja California Sur        23880  26.009791 -111.345252
# 3          Los Cabos  Baja California Sur        23400  23.059836 -109.702515
# 4             Ixtapa              Chiapas      unkwown  16.807623  -92.898650
# ..               ...                  ...          ...        ...         ...
# 108       Tecozautla              Hidalgo      unkwown  20.539699  -99.652609
# 109         Zempoala              Hidalgo      unkwown  19.925944  -98.643350
# 110          unkwown             Veracruz      unkwown  19.454313  -96.959637
# 111          Orizaba             Veracruz        94300  18.849737  -97.106006
# 112  Chiapa de Corzo              Chiapas        29160  16.601322  -92.996816
#
#        min_lat    max_lat     min_lon     max_lon  id_estado  id_municipio
# 0    22.733888  23.053888 -110.080060 -109.760060          3          3008
# 1    20.970585  21.212375  -86.995617  -86.740526         23         23005
# 2    25.969791  26.049791 -111.385252 -111.305252          3          3009
# 3    22.899836  23.219836 -109.862515 -109.542515          3          3008
# 4    16.684633  16.930706  -93.020620  -92.811072          7          7044
# ..         ...        ...         ...         ...        ...           ...
# 108  20.420234  20.659132  -99.835080  -99.449233         13         13059
# 109  19.813184  20.038677  -98.830983  -98.528064         13         13083
# 110  19.357274  19.532391  -97.106230  -96.797034         30             0
# 111  18.689737  19.009737  -97.266006  -96.946006         30         30118
# 112  16.292200  16.910330  -93.105397  -92.802283          7          7027
#
# [113 rows x 15 columns]

# %%
df_hotels['destino_id'] = [random.randint(1, len(df_destinos)) for _ in range(len(df_hotels))]
df_hotels
# Out:
#                         Razón Social            Estado            Municipio  \
# 611                      HOTEL COLON            México              Texcoco
# 913             HOTEL DULCE AMANECER            México             Timilpan
# 1014              VILLAS DE SAN JOSE            México        Tianguistenco
# 1138    IMPULSORA PLAZA DE ZACATECAS            México  Tlalnepantla de Baz
# 2007                HOTEL LA MURALLA            México               Toluca
# ...                              ...               ...                  ...
# 147551               PLAZA CAMARONES  Ciudad de México         Azcapotzalco
# 147636                        ESDISA  Ciudad de México         Azcapotzalco
# 147674            HOTELERA CAMARONES  Ciudad de México         Azcapotzalco
# 147779  HOTEL RESTAURANTE LAS GARZAS           Yucatán             Progreso
# 147802          HOTEL PROGRESO BEACH           Yucatán             Progreso
#
#                                                 Domicilio  \
# 611                                 Calle COLON 218 int 0
# 913                    Calle TULIPAN, MANZANA 3 120 int -
# 1014            Carretera LA MARQUESA TENANGO KM 23 int -
# 1138                        Avenida GUSTAVO BAZ 29 int NA
# 2007                    Avenida PASEO TOLLOCAN 1098 int -
# ...                                                   ...
# 147551                  Calle CUITLAHUAC 3369 int NINGUNO
# 147636  Calzada EJE UNO PONIENTE CALZADA VALLEJO 535 i...
# 147674                  Calzada CAMARONES 575 int NINGUNO
# 147779                           Calle 17 742 int NINGUNA
# 147802                               Calle 21 150 int N/A
#
#                                Colonia   C.P.    Teléfono  \
# 611                     Colonia CENTRO  56100  5959546946
# 913        Colonia LOMAS DE SAN MIGUEL  52928  5889966315
# 1014                    Colonia CENTRO  52600  7131330969
# 1138              Colonia XOCOYAHUALCO  54080  5576077000
# 2007    Colonia SANTA ANA TLAPALTITLÁN  50160  7221991051
# ...                                ...    ...         ...
# 147551             Colonia SAN BERNABE   2830  5550605307
# 147636      Colonia INDUSTRIAL VALLEJO   2300  5550605307
# 147674   Colonia SANTA MARIA MANINALCO   2050  5532321808
# 147779                  Colonia CENTRO  97322  9995544222
# 147802         Colonia CENTRO PROGRESO  97320  9699355079
#
#                                    E-mail tipo_hospedaje  id_propietario  \
# 611                 elhuero23@hotmail.com          Hotel               1
# 913          reynajimenez.ger@outlook.com          Hotel               2
# 1014       hotelvillasdesanjose@gmail.com          Hotel               3
# 1138    cebaz.contador@cityexpress.con.mx          Hotel               4
# 2007              vermello@prodigy.net.mx          Hotel               5
# ...                                   ...            ...             ...
# 147551     permisoslegales.2023@gmail.com          Hotel            1305
# 147636     permisoslegales.2023@gmail.com          Hotel            1306
# 147674  JVAZQUEZRO@BURODECONNSULTORIA.COM          Hotel            1307
# 147779        facturas@hotellasgarzas.com          Hotel            1308
# 147802       CIELO_MEDINA1453@HOTMAIL.COM          Hotel            1309
#
#         destino_id
# 611             82
# 913             15
# 1014             4
# 1138            95
# 2007            36
# ...            ...
# 147551          56
# 147636          82
# 147674         105
# 147779          63
# 147802          12
#
# [1309 rows x 11 columns]

# %% [markdown]
# ### Export to csv

# %%
df_hoteles.to_csv('hospedajes_hoteles.csv', index=False)
df_propietarios.to_csv('propietarios_hoteles.csv', index=False)
df_direcciones.to_csv('direcciones_hoteles.csv', index=False)
