# %%
import pandas as pd

# %%
df_hoteles = pd.read_csv('./hospedajes_hoteles.csv')
df_hoteles_colab = pd.read_csv('./hospedajes_hoteles_colab.csv')
df_propietarios = pd.read_csv('./propietarios_hoteles.csv')
df_propietarios_colab = pd.read_csv('./propietarios_hoteles_colab.csv')
df_direcciones = pd.read_csv('./direcciones_hoteles.csv')
df_direcciones_colab = pd.read_csv('./direcciones_hoteles_colab.csv')

# %%
df_hoteles = pd.concat([df_hoteles, df_hoteles_colab], ignore_index=True)
df_propietarios = pd.concat([df_propietarios, df_propietarios_colab], ignore_index=True)
df_direcciones = pd.concat([df_direcciones, df_direcciones_colab], ignore_index=True)

# %%
def add_destino_id(fila):
    for index, row in df_destinos.iterrows():
        if (fila.lat >= row.min_lat and fila.lat <= row.max_lat) and (fila.lon >= row.min_lon and fila.lon <= row.max_lon):
            return index+1
    return 0

# %%
df_destinos = pd.read_csv('../destinos/destinos.csv')

# %%
df_hoteles['destino_id'] = df_direcciones.apply(add_destino_id, axis=1)
# Out:
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# Guadalajara
# ...

# %%
len(df_hoteles['destino_id'].unique())
# Out:
# 33

# %%
df_hoteles.to_csv('./hoteles_merged_with_colab.csv', index=False)
df_propietarios.to_csv('./propietarios_merged_with_colab.csv', index=False)
df_direcciones.to_csv('./direcciones_merged_with_colab.csv', index=False)
